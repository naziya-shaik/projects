# %% [markdown]
# <a href="https://colab.research.google.com/github/naziya-shaik/projects/blob/main/instagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task1**:Removing Unwanted Columns and Renaming Appropriate Columns for Improved Analysis
# Data Cleaning for Comments is a process of removing unwanted columns and renaming the appropriate columns in a dataset containing comments. It involves identifying and removing irrelevant or redundant columns and renaming the columns to make them more descriptive and consistent with the content of the dataset. This improves the quality and usability of the data for analysis and modeling purposes.
#     #rename columns, only these columns are allowed in the dataset
#     # 1.	id
#     # 2.	comment_text
#     # 3.	user_id
#     # 4.	photo_id
#     # 5.	created_at

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0c977641-c650-4e7f-99af-512d857052bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c977641-c650-4e7f-99af-512d857052bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
import io
comments=pd.read_csv(io.BytesIO(uploaded['comments.csv']))

# %%
comments.head()
# Out:
#    id                 comment  User  id  Photo id created Timestamp  \
# 0   1         unde at dolorem         2         1  13-04-2023 08:04
# 1   2         quae ea ducimus         3         1  13-04-2023 08:04
# 2   3      alias a voluptatum         5         1  13-04-2023 08:04
# 3   4    facere suscipit sunt        14         1  13-04-2023 08:04
# 4   5  totam eligendi quaerat        17         1  13-04-2023 08:04
#
#   posted date emoji used  Hashtags used count
# 0    April 14        yes                    1
# 1    April 14         no                    2
# 2    April 14         no                    4
# 3    April 14        yes                    2
# 4    April 14        yes                    1

# %%
#task1:
comments.drop(['posted date','emoji used','Hashtags used count'],axis=1,inplace=True)
comments.set_axis(['id', 'comment_text', 'user_id','photo_id','created_at'], axis=1, inplace=True)
# Out:
# <ipython-input-6-bfc7313e5d77>:2: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   comments.set_axis(['id', 'comment_text', 'user_id','photo_id','created_at'], axis=1, inplace=True)

# %%
comments.head()
# Out:
#    id            comment_text  user_id  photo_id        created_at
# 0   1         unde at dolorem        2         1  13-04-2023 08:04
# 1   2         quae ea ducimus        3         1  13-04-2023 08:04
# 2   3      alias a voluptatum        5         1  13-04-2023 08:04
# 3   4    facere suscipit sunt       14         1  13-04-2023 08:04
# 4   5  totam eligendi quaerat       17         1  13-04-2023 08:04

# %% [markdown]
# **Task2:**Removing Unwanted Columns and Renaming Appropriate Columns for Improved Analysis
# Data Cleaning for follows is a process of removing unwanted columns and renaming the appropriate columns in a dataset containing follows. It involves identifying and removing irrelevant or redundant columns and renaming the columns to make them more descriptive and consistent with the content of the dataset. This improves the quality and usability of the data for analysis and modeling purposes.

# %%
#task2:
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-faa11d0e-f79f-4325-9696-b0b40b7ea3cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-faa11d0e-f79f-4325-9696-b0b40b7ea3cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
follows=pd.read_csv(io.BytesIO(uploaded['follows.csv']))

# %%
follows.head()
# Out:
#    follower  followee       created time  is follower active  \
# 0         2          1  13-04-2023 08:04                   1
# 1         2          3  13-04-2023 08:04                   0
# 2         2          4  13-04-2023 08:04                   0
# 3         2          5  13-04-2023 08:04                   0
# 4         2          6  13-04-2023 08:04                   1
#
#   followee Acc status
# 0             Private
# 1             private
# 2              public
# 3             private
# 4             private

# %%
follows.drop(['is follower active','followee Acc status'],axis=1,inplace=True)
follows.set_axis(['follower_id','followee_id','created_at'], axis=1, inplace=True)
# Out:
# <ipython-input-11-cb5c5ec6c93d>:2: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   follows.set_axis(['follower_id','followee_id','created_at'], axis=1, inplace=True)

# %%
follows.head()
# Out:
#    follower_id  followee_id        created_at
# 0            2            1  13-04-2023 08:04
# 1            2            3  13-04-2023 08:04
# 2            2            4  13-04-2023 08:04
# 3            2            5  13-04-2023 08:04
# 4            2            6  13-04-2023 08:04

# %% [markdown]
# **Task3:**    #rename columns, only these columns are allowed in the dataset
#     # 1.	user_id
#     # 2.	photo_id
#     # 3.	created_at

# %%
#task3:
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-619c5be1-55cb-4f9e-8490-eb061465d5ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-619c5be1-55cb-4f9e-8490-eb061465d5ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
likes=pd.read_csv(io.BytesIO(uploaded['likes.csv']))

# %%
likes.drop(['following or not','like type'],axis=1,inplace=True)
likes.set_axis(['user_id', 'photo_id', 'created_at'], axis=1, inplace=True)
# Out:
# <ipython-input-17-21485ee21b22>:2: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   likes.set_axis(['user_id', 'photo_id', 'created_at'], axis=1, inplace=True)

# %%
likes.head()
# Out:
#    user_id  photo_id        created_at
# 0        2         1  13-04-2023 08:04
# 1        2         4  13-04-2023 08:04
# 2        2         8  13-04-2023 08:04
# 3        2         9  13-04-2023 08:04
# 4        2        10  13-04-2023 08:04

# %% [markdown]
# **Task4**    #rename columns, only these columns are allowed in the dataset
#     # 1.	photo_id
#     # 2.	tag_id

# %%
#task4:
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4db5e7ed-98a5-4ee0-8464-e6f0f8fe390b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4db5e7ed-98a5-4ee0-8464-e6f0f8fe390b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
photo_tags=pd.read_csv(io.BytesIO(uploaded['photo_tags.csv']))

# %%
photo_tags.head()
# Out:
#    photo  tag ID  user id
# 0      1      13        1
# 1      1      17        1
# 2      1      18        2
# 3      1      19        2
# 4      1      21        3

# %%
photo_tags.drop(['user id'],axis =1,inplace=True)
photo_tags.rename(columns = {'photo':'photo_id','tag ID':'tag_id'},inplace=True)

# %%
photo_tags.head()
# Out:
#    photo_id  tag_id
# 0         1      13
# 1         1      17
# 2         1      18
# 3         1      19
# 4         1      21

# %% [markdown]
# **Task5:**#rename columns, only these columns are allowed in the dataset
#     # 1.	id
#     # 2.	image_url
#     # 3.	user_id
#     # 4.	created_date

# %%
#task5:
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-6929a60e-5351-422c-960c-b94b14c87052" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6929a60e-5351-422c-960c-b94b14c87052">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
photos=pd.read_csv(io.BytesIO(uploaded['photos.csv']))

# %%
photos.head()
# Out:
#    id            image link  user ID       created dat Insta filter used  \
# 0   1     http://elijah.biz        1  13-04-2023 08:04               yes
# 1   2    https://shanon.org        1  13-04-2023 08:04                no
# 2   3      http://vicky.biz        1  13-04-2023 08:04                no
# 3   4      http://oleta.net        1  13-04-2023 08:04                no
# 4   5  https://jennings.biz        1  13-04-2023 08:04               yes
#
#   photo type
# 0      photo
# 1      photo
# 2      photo
# 3      photo
# 4      photo

# %%
photos.drop(['Insta filter used','photo type'],axis=1,inplace=True)
photos.rename(columns = {'image link':'image_url','user ID':'user_id','created dat':'created_date'},inplace=True)

# %%
photos.head()
# Out:
#    id             image_url  user_id      created_date
# 0   1     http://elijah.biz        1  13-04-2023 08:04
# 1   2    https://shanon.org        1  13-04-2023 08:04
# 2   3      http://vicky.biz        1  13-04-2023 08:04
# 3   4      http://oleta.net        1  13-04-2023 08:04
# 4   5  https://jennings.biz        1  13-04-2023 08:04

# %% [markdown]
# **Task6:**    #rename columns, only these columns are allowed in the dataset
#     # 1.	id
#     # 2.	tag_name
#     # 3.	created_at

# %%
#task6:
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d2d15a8a-f633-46d0-bb7a-4f7f63ad8a72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2d15a8a-f633-46d0-bb7a-4f7f63ad8a72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
tags=pd.read_csv(io.BytesIO(uploaded['tags.csv']))

# %%
tags.head()
# Out:
#    id     tag text      created time       location
# 0   1       sunset  13-04-2023 08:04        florida
# 1   2  photography  13-04-2023 08:04  washington DC
# 2   3      sunrise  13-04-2023 08:04       new york
# 3   4    landscape  13-04-2023 08:04         london
# 4   5         food  13-04-2023 08:04         brazil

# %%
tags.drop(['location'],axis=1,inplace=True)
tags.rename(columns = {'tag text':'tag_name','created time':'created_at'},inplace=True)

# %%
tags.head()
# Out:
#    id     tag_name        created_at
# 0   1       sunset  13-04-2023 08:04
# 1   2  photography  13-04-2023 08:04
# 2   3      sunrise  13-04-2023 08:04
# 3   4    landscape  13-04-2023 08:04
# 4   5         food  13-04-2023 08:04

# %% [markdown]
# **Task7:**    #rename columns, only these columns are allowed in the dataset
#     # 1.	id
#     # 2.	username
#     # 3.	created_at

# %%
#task7:
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9a9b73b6-cb8c-4afe-bfc2-fcf85594c538" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a9b73b6-cb8c-4afe-bfc2-fcf85594c538">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
users=pd.read_csv(io.BytesIO(uploaded['users.csv']))

# %%
users.head()
# Out:
#    id           name      created time private/public  post count  \
# 0   1  Kenton_Kirlin  16-02-2017 18:22            yes          11
# 1   2  Andre_Purdy85  02-04-2017 17:11             no           7
# 2   3  Harley_Lind18  21-02-2017 11:12             no           2
# 3   4  Arely_Bogan63  13-08-2016 01:28            yes           1
# 4   5  Aniya_Hackett  07-12-2016 01:04            yes           3
#
#   Verified status
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no

# %%
users.drop(['private/public','post count','Verified status'],axis=1,inplace=True)
users.rename(columns={'name':'username','created time':'created_at'},inplace=True)

# %%
users.head()
# Out:
#    id       username        created_at
# 0   1  Kenton_Kirlin  16-02-2017 18:22
# 1   2  Andre_Purdy85  02-04-2017 17:11
# 2   3  Harley_Lind18  21-02-2017 11:12
# 3   4  Arely_Bogan63  13-08-2016 01:28
# 4   5  Aniya_Hackett  07-12-2016 01:04
